# %%
import pandas as pd
import yfinance as yf
import numpy as np
import datetime as dt
import copy
import matplotlib.pyplot as plt
from yahooquery import Ticker
import time

# %%
#importando base
df_ibrx = pd.read_excel(r'C:\Users\drsan\OneDrive\Área de Trabalho\Python\ETFs_Onshore.xlsx',sheet_name = 'IBRX100')
df_ibrx.head()
# Out:
#   Código           Ação   Tipo  Qtde. Teórica  Part. (%)                Setor  \
# 0   ABEV3     AMBEV S/A     ON  4.354.228.928     2936.0  Consumo não Cíclico
# 1   ALPA4    ALPARGATAS  PN N1    187.007.704      328.0      Consumo Cíclico
# 2   ALSO3  ALIANSCSONAE  ON NM    127.374.163      186.0           Financeiro
# 3   AZUL4          AZUL  PN N2    317.471.474      363.0     Bens Industriais
# 4   B3SA3            B3  ON NM  2.046.021.644     6301.0           Financeiro
#
#                         Subsetor                       Segmento
# 0                        Bebidas       Cervejas e Refrigerantes
# 1  Tecidos, Vestuário e Calçados                       Calçados
# 2          Exploração de Imóveis          Exploração de Imóveis
# 3                     Transporte               Transporte Aéreo
# 4  Serviços Financeiros Diversos  Serviços Financeiros Diversos

# %%
# dando aquele tapa
df = df_ibrx
df = pd.DataFrame(df) 
df = df.dropna()
df['Part. (%)'] /= 100000
df.rename(columns={'Código\xa0':'Codigo'}, inplace = True)
df['Codigo'] = df['Codigo'] + ".SA"
tickers = df['Codigo']

# %%
#auxiliares estrategias
def stochastic(x,a,b):
    # x = matriz de precos
    # a = periodo stochastic
    # b = signal
    df = x.copy()
    df['%K'] = (df['Close']-df['Low'].rolling(a).min())/(df['High'].rolling(a).max()-df['Low'].rolling(a).min())*100
    df['%D'] = df['%K'].rolling(b).mean()
    return df

def MACD(x,a,b,c):
    # x = matriz de precos
    # a = fast mov avg
    # b = slow mov avg
    # c = signal
    df = x.copy()
    df['MACD'] = df['Close'].ewm(span=a).mean() - df['Close'].ewm(span=b).mean()
    df['MACD_Signal'] = df['MACD'].ewm(span=c).mean()
    return df

def SMA(x,a,b):
    # x = matriz de precos
    # a = fast mov avg
    # b = slow mov avg
    df = x.copy()
    df['SMA_Fast'] = df['Close'].rolling(a).mean()
    df['SMA_Slow'] = df['Close'].rolling(b).mean()
    return df

def EMA(x,a,b):
    # x = matriz de precos
    # a = fast mov avg
    # b = slow mov avg
    df = x.copy()
    df['EMA_Fast'] = df['Close'].ewm(span=a).mean()
    df['EMA_Slow'] = df['Close'].ewm(span=b).mean()
    return df

# %%
def trades(x,y):
    # x = matriz de precos com trade_signal
    # y e o ativo
    df = x.copy()
    df_trades = pd.DataFrame(columns=['ativo','data_entrada','preco_entrada','data_saida','preco_saida','periodos'])
    ativo = y
    
    for i in range(len(df)):
        
        if i == 0:
            if df['trade_signal'][i] == 'Buy':
                data_entrada = df.index[i]
                preco_entrada = df['Close'][i]
                contador = i
                                        
        elif df['trade_signal'][i-1] == '' and df['trade_signal'][i] == 'Buy':          
            data_entrada = df.index[i]
            preco_entrada = df['Close'][i]
            contador = i
            
        elif df['trade_signal'][i-1] == 'Buy' and df['trade_signal'][i] == '':
            data_saida = df.index[i]
            preco_saida = df['Close'][i]
            periodos = i - contador
            df_trades.loc[len(df_trades)] = [ativo,data_entrada,preco_entrada,data_saida,preco_saida,periodos]
    
    df_trades['return'] = df_trades['preco_saida']/df_trades['preco_entrada'] - 1
    return df_trades

# %%
def trades_KPIs(x):
    # x = matriz de trades
    global prices
    df = x.copy()
    df_KPIs = pd.DataFrame({'return':[df['return'].mean()]})
    
    #return
    df_KPIs['return'] = df['return'].mean()
    df_KPIs['vol'] = df['return'].std()
    df_KPIs['sharpe'] = df_KPIs['return']/df_KPIs['vol']

    #trades
    df_KPIs['qtd_trades'] = len(df)
    df_KPIs['daily_trades'] = df_KPIs['qtd_trades']/len(prices[list(prices.keys())[0]])
    df_KPIs['win_trades'] = len(df[df['return']>0])
    df_KPIs['win_ratio'] = df_KPIs['win_trades'] / df_KPIs['qtd_trades']
    df_KPIs['avg_duration'] = df['periodos'].mean()
    df_KPIs['daily_return'] = ((df_KPIs['return']+1)**(1/df_KPIs['avg_duration'])-1)*df_KPIs['daily_trades']
    df_KPIs['CAGR'] = ((df_KPIs['daily_return']+1)**(252))-1
    
    #avg ratios
    df_KPIs['avg_win'] = df[df['return']>0]['return'].mean()
    df_KPIs['avg_loss'] = df[df['return']<=0]['return'].mean()
    df_KPIs['avg_win_vs_loss'] = df_KPIs['avg_win']/abs(df_KPIs['avg_loss'])
    df_KPIs['top_win'] = df[df['return']>0]['return'].max()
    df_KPIs['top_loss'] = df[df['return']<=0]['return'].min()
    
    return df_KPIs

# %%
def qtd_trades(x,y):
    # x = matriz de precos com trade_signal
    # y e o ativo
    df = x.copy()
    ativo = y

    df_qtd_trades = pd.DataFrame(index = df.index)
    df_qtd_trades[ativo] = [1 if (df['trade_signal'][i] == 'Buy' and i == 0)
                            or (i != 0 and (df['trade_signal'][i] == 'Buy' or df['trade_signal'][i-1] == 'Buy'))
                            else 0 for i in range(len(df))]

    return df_qtd_trades

# %%
def trade_signal(x):
    # x = matriz de precos
    df = x.copy()
    df = stochastic(EMA(SMA(df,5,20),5,20),20,3)
    df['trade_signal'] = ''
    df['return'] = float(0)
    
    for i in range(len(df)):
        
        if df['trade_signal'][i-1] == '':
            if df['Close'][i] > df['EMA_Fast'][i] and df['Close'][i] < df['SMA_Slow'][i] and \
            df['%K'][i] < 30:
                df['trade_signal'][i] = 'Buy'
        
        if df['trade_signal'][i-1] == "Buy":
            df['return'][i] = df['Close'][i] / df['Close'][i-1] - 1
            if df['Close'][i] <= df['EMA_Fast'][i] or df['Close'][i] >= df['SMA_Slow'][i] or \
            df['%K'][i] > 50:
                df['trade_signal'][i] = ''
            else:
                df['trade_signal'][i] = 'Buy'
              
    return df

# %%
start = dt.date.today() + dt.timedelta(1) - dt.timedelta(1080) #59 para intraday, 1080 para diario
end = dt.date.today() + dt.timedelta(1)
prices = {}
interval = '1d' #1d para diario, 5m para 5minutos
for t in tickers:
    try:
        prices[t] = yf.download(t,start=start,end=end,interval=interval)
    except: 
        continue
    prices[t].dropna(how='all', inplace = True)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
tickers2 = tickers[:]
portfolio = {}
df_trades = pd.DataFrame()
df_qtd_trades = pd.DataFrame()
returns = pd.DataFrame()
for t in tickers2:
    print(t, "passthrough at ",time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(time.time())))
    portfolio[t] = trade_signal(prices[t])
    df_trades = pd.concat([df_trades,trades(portfolio[t],t)])
    df_trades.reset_index(drop=True, inplace=True)
    df_qtd_trades = pd.concat([df_qtd_trades,qtd_trades(portfolio[t],t)], axis=1)
    returns[t] = portfolio[t]['return']
returns['total'] = (returns+1).cumprod().mean(axis=1)
# Out:
# ABEV3.SA passthrough at  2020-09-08 20:42:51
# C:\Users\drsan\anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\drsan\anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# C:\Users\drsan\anaconda3\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\drsan\anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ALPA4.SA passthrough at  2020-09-08 20:42:52
# ALSO3.SA passthrough at  2020-09-08 20:42:52
# AZUL4.SA passthrough at  2020-09-08 20:42:52
# B3SA3.SA passthrough at  2020-09-08 20:42:52
# BBAS3.SA passthrough at  2020-09-08 20:42:52
# BBDC3.SA passthrough at  2020-09-08 20:42:53
# BBDC4.SA passthrough at  2020-09-08 20:42:53
# BBSE3.SA passthrough at  2020-09-08 20:42:53
# BEEF3.SA passthrough at  2020-09-08 20:42:53
# BIDI11.SA passthrough at  2020-09-08 20:42:54
# BPAC11.SA passthrough at  2020-09-08 20:42:54
# BPAN4.SA passthrough at  2020-09-08 20:42:54
# BRAP4.SA passthrough at  2020-09-08 20:42:54
# BRDT3.SA passthrough at  2020-09-08 20:42:54
# BRFS3.SA passthrough at  2020-09-08 20:42:55
# BRKM5.SA passthrough at  2020-09-08 20:42:55
# BRML3.SA passthrough at  2020-09-08 20:42:55
# BRSR6.SA passthrough at  2020-09-08 20:42:55
# BTOW3.SA passthrough at  2020-09-08 20:42:56
# CCRO3.SA passthrough at  2020-09-08 20:42:56
# CESP6.SA passthrough at  2020-09-08 20:42:56
# CIEL3.SA passthrough at  2020-09-08 20:42:56
# CMIG4.SA passthrough at  2020-09-08 20:42:56
# COGN3.SA passthrough at  2020-09-08 20:42:57
# CPFE3.SA passthrough at  2020-09-08 20:42:57
# CPLE6.SA passthrough at  2020-09-08 20:42:57
# CRFB3.SA passthrough at  2020-09-08 20:42:57
# CSAN3.SA passthrough at  2020-09-08 20:42:58
# CSMG3.SA passthrough at  2020-09-08 20:42:58
# CSNA3.SA passthrough at  2020-09-08 20:42:58
# CVCB3.SA passthrough at  2020-09-08 20:42:58
# CYRE3.SA passthrough at  2020-09-08 20:42:58
# DTEX3.SA passthrough at  2020-09-08 20:42:59
# ECOR3.SA passthrough at  2020-09-08 20:42:59
# EGIE3.SA passthrough at  2020-09-08 20:42:59
# ELET3.SA passthrough at  2020-09-08 20:42:59
# ELET6.SA passthrough at  2020-09-08 20:42:59
# EMBR3.SA passthrough at  2020-09-08 20:43:00
# ENBR3.SA passthrough at  2020-09-08 20:43:00
# ENEV3.SA passthrough at  2020-09-08 20:43:00
# ENGI11.SA passthrough at  2020-09-08 20:43:00
# EQTL3.SA passthrough at  2020-09-08 20:43:01
# EZTC3.SA passthrough at  2020-09-08 20:43:01
# FLRY3.SA passthrough at  2020-09-08 20:43:01
# GGBR4.SA passthrough at  2020-09-08 20:43:01
# GNDI3.SA passthrough at  2020-09-08 20:43:01
# GOAU4.SA passthrough at  2020-09-08 20:43:02
# GOLL4.SA passthrough at  2020-09-08 20:43:02
# HAPV3.SA passthrough at  2020-09-08 20:43:02
# HGTX3.SA passthrough at  2020-09-08 20:43:02
# HYPE3.SA passthrough at  2020-09-08 20:43:02
# IGTA3.SA passthrough at  2020-09-08 20:43:03
# IRBR3.SA passthrough at  2020-09-08 20:43:03
# ITSA4.SA passthrough at  2020-09-08 20:43:03
# ITUB4.SA passthrough at  2020-09-08 20:43:03
# JBSS3.SA passthrough at  2020-09-08 20:43:04
# KLBN11.SA passthrough at  2020-09-08 20:43:04
# LAME4.SA passthrough at  2020-09-08 20:43:04
# LCAM3.SA passthrough at  2020-09-08 20:43:04
# LIGT3.SA passthrough at  2020-09-08 20:43:04
# LINX3.SA passthrough at  2020-09-08 20:43:05
# LREN3.SA passthrough at  2020-09-08 20:43:05
# MDIA3.SA passthrough at  2020-09-08 20:43:05
# MGLU3.SA passthrough at  2020-09-08 20:43:05
# MOVI3.SA passthrough at  2020-09-08 20:43:05
# MRFG3.SA passthrough at  2020-09-08 20:43:06
# MRVE3.SA passthrough at  2020-09-08 20:43:06
# MULT3.SA passthrough at  2020-09-08 20:43:06
# MYPK3.SA passthrough at  2020-09-08 20:43:06
# NEOE3.SA passthrough at  2020-09-08 20:43:07
# NTCO3.SA passthrough at  2020-09-08 20:43:07
# PCAR3.SA passthrough at  2020-09-08 20:43:07
# PETR3.SA passthrough at  2020-09-08 20:43:07
# PETR4.SA passthrough at  2020-09-08 20:43:07
# PRIO3.SA passthrough at  2020-09-08 20:43:07
# PSSA3.SA passthrough at  2020-09-08 20:43:08
# QUAL3.SA passthrough at  2020-09-08 20:43:08
# RADL3.SA passthrough at  2020-09-08 20:43:08
# RAIL3.SA passthrough at  2020-09-08 20:43:08
# RAPT4.SA passthrough at  2020-09-08 20:43:08
# RENT3.SA passthrough at  2020-09-08 20:43:09
# SANB11.SA passthrough at  2020-09-08 20:43:09
# SAPR11.SA passthrough at  2020-09-08 20:43:09
# SBSP3.SA passthrough at  2020-09-08 20:43:09
# SMLS3.SA passthrough at  2020-09-08 20:43:09
# SULA11.SA passthrough at  2020-09-08 20:43:10
# SUZB3.SA passthrough at  2020-09-08 20:43:10
# TAEE11.SA passthrough at  2020-09-08 20:43:10
# TCSA3.SA passthrough at  2020-09-08 20:43:10
# TIMP3.SA passthrough at  2020-09-08 20:43:11
# TOTS3.SA passthrough at  2020-09-08 20:43:11
# TRPL4.SA passthrough at  2020-09-08 20:43:11
# UGPA3.SA passthrough at  2020-09-08 20:43:11
# USIM5.SA passthrough at  2020-09-08 20:43:12
# VALE3.SA passthrough at  2020-09-08 20:43:12
# VIVT4.SA passthrough at  2020-09-08 20:43:12
# VVAR3.SA passthrough at  2020-09-08 20:43:12
# WEGE3.SA passthrough at  2020-09-08 20:43:12
# YDUQ3.SA passthrough at  2020-09-08 20:43:13

# %%
#KPIs trades
trades_KPIs(df_trades)
# Out:
#      return       vol    sharpe  qtd_trades  daily_trades  win_trades  \
# 0  0.000815  0.041902  0.019444        1519      2.072306         526
#
#    win_ratio  avg_duration  daily_return      CAGR   avg_win  avg_loss  \
# 0    0.34628      1.895984       0.00089  0.251411  0.042705 -0.021375
#
#    avg_win_vs_loss   top_win  top_loss
# 0          1.99791  0.403704  -0.21358

# %%
#best trades
df_trades.sort_values(by=['return'], ascending=False).head(10)
# Out:
#           ativo data_entrada  preco_entrada data_saida  preco_saida periodos  \
# 774    GOLL4.SA   2020-03-24       8.100000 2020-03-31    11.370000        5
# 526    CVCB3.SA   2020-03-24       8.750000 2020-03-31    11.100000        5
# 175   BIDI11.SA   2020-03-20      27.700001 2020-03-26    33.990002        4
# 748    GNDI3.SA   2020-03-20      39.990002 2020-03-25    48.500000        3
# 1032   MRFG3.SA   2020-03-23       7.430000 2020-03-30     8.950000        5
# 696    EZTC3.SA   2020-05-15      25.940001 2020-05-21    31.200001        4
# 800    HGTX3.SA   2020-05-15      11.970000 2020-05-21    14.190000        4
# 836    IRBR3.SA   2020-03-24       8.180000 2020-03-31     9.680000        5
# 40     ALSO3.SA   2020-05-19      22.500000 2020-05-21    26.600000        2
# 1501   WEGE3.SA   2020-03-20      32.369999 2020-03-26    37.950001        4
#
#         return
# 774   0.403704
# 526   0.268571
# 175   0.227076
# 748   0.212803
# 1032  0.204576
# 696   0.202776
# 800   0.185464
# 836   0.183374
# 40    0.182222
# 1501  0.172382

# %%
#worst trades
df_trades.sort_values(by=['return'], ascending=True).head(10)
# Out:
#          ativo data_entrada  preco_entrada data_saida  preco_saida periodos  \
# 1419  UGPA3.SA   2020-03-13      16.200001 2020-03-16        12.74        1
# 1031  MRFG3.SA   2020-03-13       9.190000 2020-03-16         7.58        1
# 231   BRFS3.SA   2018-02-28      29.920000 2018-03-05        24.75        3
# 524   CVCB3.SA   2020-03-06      22.879999 2020-03-09        19.50        1
# 525   CVCB3.SA   2020-03-10      21.760000 2020-03-11        19.24        1
# 1074  MYPK3.SA   2020-03-25      12.300000 2020-03-30        10.98        3
# 552   DTEX3.SA   2020-03-25      10.470000 2020-03-31         9.35        4
# 510   CSNA3.SA   2020-04-02       6.970000 2020-04-03         6.25        1
# 1016  MOVI3.SA   2020-03-25       9.750000 2020-03-30         8.80        3
# 611   ELET6.SA   2018-05-22      20.700001 2018-05-23        18.75        1
#
#         return
# 1419 -0.213580
# 1031 -0.175190
# 231  -0.172794
# 524  -0.147727
# 525  -0.115809
# 1074 -0.107317
# 552  -0.106972
# 510  -0.103300
# 1016 -0.097436
# 611  -0.094203

# %%
#histograma retornos
(df_trades['return']).plot.hist()

# %%
#retorno carteira usando MEDIA
returns['total'].plot()

# %%
#quantidade trades por dia
df_trades.groupby(['data_entrada']).count()['ativo'].plot()

# %%
# histograma trades por dia
df_trades.groupby(['data_entrada']).count()['ativo'].plot.hist()

# %%
# grafico utilizacao do portfolio
plt.figure(figsize=(15,5))
plt.plot(df_qtd_trades.sum(axis=1)/len(portfolio.keys()), label ='% portfolio')
plt.hlines((df_qtd_trades.sum(axis=1)/len(portfolio.keys())).mean(), df_qtd_trades.index[0], df_qtd_trades.index[-1], label ='media')
plt.plot((df_qtd_trades.sum(axis=1)/len(portfolio.keys())).rolling(20).mean(), label ='media movel 20 periodos')
plt.legend()
plt.show()

# %%
#bovespa para comparacao
bench = pd.DataFrame()
bench = yf.download('BOVA11.SA',start,end,interval)['Close']
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# grafico estrategia vs bovespa
plt.figure(figsize=(15,5))
plt.plot((bench.shift(-1)/bench).cumprod(), label ='bovespa')
plt.plot(returns['total'], label ='estrategia')
plt.legend()
plt.show()
